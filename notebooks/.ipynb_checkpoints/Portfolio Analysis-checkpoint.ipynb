# %%
import os
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
NOTEBOOKS_DIRECTORY = os.getcwd()
DATA_DIRECTORY = os.path.join(os.path.dirname(NOTEBOOKS_DIRECTORY), 'data')

data_files = [file for file in os.listdir(DATA_DIRECTORY) if '.csv' in file.lower()]
data_files = sorted(data_files, reverse = True)
portfolio_file = os.path.join(DATA_DIRECTORY, data_files[0])
portfolio_df = pd.read_csv(portfolio_file, skiprows=3)

portfolio_df = portfolio_df[['Symbol', 'Description', 'Quantity', 'Cost Basis', '% Of Account']]
portfolio_df = portfolio_df.loc[~portfolio_df['Symbol'].isin(['Cash & Cash Investments', 'Account Total'])]
portfolio_df = portfolio_df.replace({'BRK/B':'BRK-B'})

print(portfolio_df.shape)
print(portfolio_df.info())

portfolio_df.head(5)
# Out:
#   Symbol                                        Description Quantity  \
# 0      T                                        A T & T INC  30.1413
# 1   ADBE                                          ADOBE INC        4
# 2   BABA  ALIBABA GROUP HOLDING F SPONSORED ADR 1 ADR RE...        5
# 3   AAPL                                          APPLE INC  10.0269
# 4  BRK-B                         BERKSHIRE HATHAWAY CLASS B        9
#
#   Cost Basis % Of Account
# 0    $888.90        2.99%
# 1  $1,308.00        5.11%
# 2    $933.00        3.56%
# 3  $2,504.20        10.8%
# 4  $1,679.00        5.33%

# %%
def get_profile_data(portfolio, attribute):
    """
    Company Profile of Items
    """
    
    stock = portfolio['Symbol']
    profile = requests.get(f'https://financialmodelingprep.com/api/v3/company/profile/{stock}')
    profile = profile.json()
    
    try:
        return profile['profile'][attribute]
    except:
        return None

def get_quote_data(portfolio, attribute):
    """
    Company Quote Group of Items
    """
    
    stock = portfolio['Symbol']
    company_quote = requests.get(f'https://financialmodelingprep.com/api/v3/quote/{stock}')
    company_quote = company_quote.json()
    
    try:
        return float('{0:.2f}'.format(company_quote[0][attribute]))
    except:
        return None

def get_balance_sheet_data(portfolio, attribute, quarter):
    """
    Balance Sheet Group of Items
    """
    
    stock = portfolio['Symbol']
    bs = requests.get(f"https://financialmodelingprep.com/api/v3/financials/balance-sheet-statement/{stock}?period=quarter")
    bs = bs.json()
    
    try:
        return bs['financials'][quarter][attribute]
    except:
        return None

def get_income_statement_data(portfolio, attribute, quarter):
    """
    Income Statement Group of Items
    """
    
    stock = portfolio['Symbol']
    income_stat = requests.get(f"https://financialmodelingprep.com/api/v3/financials/income-statement/{stock}?period=quarter")
    income_stat = income_stat.json()
    
    try:
        return income_stat['financials'][quarter][attribute]
    except:
        return None

# %%
portfolio_df['price'] = portfolio_df.apply(lambda stock: get_quote_data(stock, 'price'), axis=1)

# %%
portfolio_df
# Out:
#    Symbol                                        Description Quantity  \
# 0       T                                        A T & T INC  30.1413
# 1    ADBE                                          ADOBE INC        4
# 2    BABA  ALIBABA GROUP HOLDING F SPONSORED ADR 1 ADR RE...        5
# 3    AAPL                                          APPLE INC  10.0269
# 4   BRK-B                         BERKSHIRE HATHAWAY CLASS B        9
# 5      FB                               FACEBOOK INC CLASS A        6
# 6      GD                                GENERAL DYNAMICS CO        4
# 7    GILD                                GILEAD SCIENCES INC       10
# 8     HON                                 HONEYWELL INTL INC       10
# 9     JPM                              J P MORGAN CHASE & CO        5
# 10     KR                                          KROGER CO       20
# 11      M                                          MACYS INC  70.1538
# 12     MA                             MASTERCARD INC CLASS A   2.0029
# 13    MRK                                   MERCK & CO. INC.       10
# 14     MU                                  MICRON TECHNOLOGY        2
# 15   MSFT                                     MICROSOFT CORP        5
# 16    NEE                                 NEXTERA ENERGY INC        2
# 17    NVS   NOVARTIS AG F SPONSORED ADR 1 ADR REPS 1 ORD SHS        5
# 18    PPL                                           PPL CORP       18
# 19   QCOM                                       QUALCOMM INC        8
# 20      O                              REALTY INCM CORP REIT   7.0093
# 21  RHHBY  ROCHE HLDG AG F SPONSORED ADR 1 ADR RE 0.125 O...        5
# 22   ROKU                                 ROKU I N C CLASS A       10
# 23    SNY  SANOFI S A F SPONSORED ADR 1 ADR REPS 0.5 ORD SHS        5
# 24   SWKS                                 SKYWORKS SOLUTIONS        2
# 25     VZ                                VERIZON COMMUNICATN       15
# 26    DIS                                     WALT DISNEY CO        7
# 27     WM                               WASTE MANAGEMENT INC        7
# 28    XRX                                XEROX HOLDINGS CORP  54.1013
# 29   FLIN                            FRANKLIN FTSE INDIA ETF       20
# 30   SPHD   INVESCO S&P 500 HIGH DIVIDEND LOW VOLATILITY ETF   5.0521
# 31   SCHR                SCHWAB INTERMEDIATE TERM US TRS ETF  10.0247
# 32   SPDW                SPDR PORTFOLIO DVLPD WRLD EX-US ETF       12
# 33   SPTM               SPDR PORTFOLIO S P 1500 CMPST ST ETF  12.0521
# 34   SPYD                     SPDR S&P 500 HIGH DIVIDEND ETF   9.0478
# 35    VEA                VANGUARD FTSE DEVELOPED MARKETS ETF    2.008
# 36    VWO                 VANGUARD FTSE EMERGING MARKETS ETF   8.0037
# 37    VUG                                VANGUARD GROWTH ETF   3.0078
# 38    VYM                   VANGUARD HIGH DIVIDEND YIELD ETF   2.0159
# 39   VGIT                VANGUARD INTRMDIAT TRM TRSRY ETF IV   2.0057
# 40    VBK                      VANGUARD SMALL CAP GROWTH ETF   2.0035
# 41    BND                     VANGUARD TOTAL BOND MARKET ETF   6.0185
# 42   BNDX                VANGUARD TOTAL INTERNATL BND ETF IV   7.0085
# 43    VTI                    VANGUARD TOTAL STOCK MARKET ETF   1.0049
#
#    Cost Basis % Of Account   price
# 0     $888.90        2.99%   28.31
# 1   $1,308.00        5.11%  365.30
# 2     $933.00        3.56%  203.68
# 3   $2,504.20        10.8%  307.71
# 4   $1,679.00        5.33%  169.25
# 5   $1,016.00        4.43%  210.88
# 6     $510.00        1.83%  130.92
# 7     $715.00        2.67%   76.26
# 8   $1,357.00        4.39%  125.41
# 9     $445.00         1.5%   85.90
# 10    $629.00        2.28%   32.51
# 11    $350.16         1.3%    5.31
# 12    $505.80        1.96%  278.94
# 13    $771.76        2.79%   79.78
# 14     $80.00        0.31%   44.41
# 15    $850.00        3.21%  183.16
# 16    $450.00        1.59%  227.85
# 17    $420.00        1.47%   84.02
# 18    $441.00        1.54%   24.51
# 19    $600.40        2.12%   75.77
# 20    $366.97        1.23%   49.99
# 21    $197.00         0.8%     NaN
# 22    $992.00        3.95%  112.93
# 23    $223.17        0.83%   47.26
# 24    $200.00        0.74%  106.22
# 25    $845.00        2.87%   54.71
# 26    $675.00        2.67%  109.05
# 27    $695.00        2.35%   95.93
# 28    $962.95        2.82%   14.89
# 29    $302.00         1.2%   17.19
# 30    $215.63        0.54%   30.57
# 31    $575.51        2.06%   58.80
# 32    $311.54        1.05%   24.98
# 33    $434.46        1.47%   34.86
# 34    $239.67        0.81%   25.46
# 35     $87.70        0.24%   34.86
# 36    $289.74           1%   35.76
# 37    $536.79        1.93%  183.15
# 38    $188.55        0.53%   74.94
# 39    $134.50         0.5%   70.57
# 40    $412.49        1.25%  177.86
# 41    $507.85        1.84%   87.35
# 42    $393.97         1.4%   57.15
# 43    $169.91        0.51%  143.83
